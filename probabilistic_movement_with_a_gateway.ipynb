# %%
import random
import folium

enlem = []
boylam = []
usage1 = []
usage2 = []
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
nodes = int(input("Please enter total number of nodes = "))
apps = int(input("Please enter number of app usage = "))

for i in range (0,nodes):

  x = random.uniform(41.1045, 41.1029)
  enlem.append(x)
  y = random.uniform(29.0239,29.0217)
  boylam.append(y)
  folium.Marker(location=[x,y],tooltip="People that is not using App").add_to(m)

folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)


for j in range (0,apps):
  blue1 = random.choice(enlem)
  usage1.append(blue1)
  blue2 = random.choice(boylam)  
  usage2.append(blue2)
  folium.Marker(location=[blue1,blue2],tooltip=j,icon=folium.Icon(color='red')).add_to(m)
  folium.CircleMarker(
      location=[blue1,blue2],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)





m
# Out:
# Please enter total number of nodes = 100
# Please enter number of app usage = 30
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step1_enlem = []   #enlem
step1_boylam = []   #boylam

def move_north(i):
  k = float(usage1[i] + 0.00005968)
  step1_enlem.append(k)
  l = usage2[i]
  step1_boylam.append(l)
  folium.Marker(location=[k,usage2[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(usage1[i] - 0.00005968)
  step1_enlem.append(k)
  l = usage2[i]
  step1_boylam.append(l)
  folium.Marker(location=[k,usage2[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(usage2[i] + 0.00005968)
  step1_boylam.append(k)
  l = usage1[i]
  step1_enlem.append(l)
  folium.Marker(location=[usage1[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(usage2[i] - 0.00005968)
  step1_boylam.append(k)
  l = usage1[i]
  step1_enlem.append(l)
  folium.Marker(location=[usage1[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step1_enlem)):
  lat1 = radians(step1_enlem[k])
  lon1 = radians(step1_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step1_enlem[i])
    lon2 = radians(step1_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 14 Result: 0.005424790437922378
# 14 Should be: 5.424790437922377 m
# 16 Result: 0.0035856421638211376
# 16 Should be: 3.5856421638211375 m
# 18 Result: 0.004187277210431975
# 18 Should be: 4.187277210431976 m
# 20 Result: 0.005699620426671688
# 20 Should be: 5.6996204266716886 m
# 20 Result: 0.0030499781212272067
# 20 Should be: 3.049978121227207 m
# 22 Result: 0.0031479472573352186
# 22 Should be: 3.1479472573352187 m
# 23 Result: 0.008331020994949277
# 23 Should be: 8.331020994949277 m
# 29 Result: 0.0061294235661365475
# 29 Should be: 6.1294235661365475 m

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step1_enlem[i],step1_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step1_enlem[i],step1_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step2_enlem = []   #enlem
step2_boylam = []   #boylam

def move_north(i):
  k = float(step1_enlem[i] + 0.00005968)
  step2_enlem.append(k)
  l = step1_boylam[i]
  step2_boylam.append(l)
  folium.Marker(location=[k,step1_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step1_enlem[i] - 0.00005968)
  step2_enlem.append(k)
  l = step1_boylam[i]
  step2_boylam.append(l)
  folium.Marker(location=[k,step1_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step1_boylam[i] + 0.00005968)
  step2_boylam.append(k)
  l = step1_enlem[i]
  step2_enlem.append(l)
  folium.Marker(location=[step1_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step1_boylam[i] - 0.00005968)
  step2_boylam.append(k)
  l = step1_enlem[i]
  step2_enlem.append(l)
  folium.Marker(location=[step1_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step2_enlem)):
  lat1 = radians(step2_enlem[k])
  lon1 = radians(step2_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step2_enlem[i])
    lon2 = radians(step2_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 3 Result: 0.0064268180180005645
# 3 Should be: 6.4268180180005645 m
# 16 Result: 0.0035856421638211376
# 16 Should be: 3.5856421638211375 m
# 20 Result: 0.005699620309701471
# 20 Should be: 5.699620309701471 m
# 22 Result: 0.006533725523110083
# 22 Should be: 6.533725523110083 m
# 23 Result: 0.008331020994949277
# 23 Should be: 8.331020994949277 m
# 29 Result: 0.0061294235661365475
# 29 Should be: 6.1294235661365475 m

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step2_enlem[i],step2_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step2_enlem[i],step2_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step3_enlem = []   #enlem
step3_boylam = []   #boylam

def move_north(i):
  k = float(step2_enlem[i] + 0.00005968)
  step3_enlem.append(k)
  l = step2_boylam[i]
  step3_boylam.append(l)
  folium.Marker(location=[k,step2_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step2_enlem[i] - 0.00005968)
  step3_enlem.append(k)
  l = step2_boylam[i]
  step3_boylam.append(l)
  folium.Marker(location=[k,step2_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step2_boylam[i] + 0.00005968)
  step3_boylam.append(k)
  l = step2_enlem[i]
  step3_enlem.append(l)
  folium.Marker(location=[step2_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step2_boylam[i] - 0.00005968)
  step3_boylam.append(k)
  l = step2_enlem[i]
  step3_enlem.append(l)
  folium.Marker(location=[step2_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step3_enlem)):
  lat1 = radians(step3_enlem[k])
  lon1 = radians(step3_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step3_enlem[i])
    lon2 = radians(step3_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 3 Result: 0.007084626305800413
# 3 Should be: 7.084626305800413 m
# 16 Result: 0.0035856421638211376
# 16 Should be: 3.5856421638211375 m
# 19 Result: 0.006518453421370206
# 19 Should be: 6.5184534213702054 m
# 22 Result: 0.006533725523110083
# 22 Should be: 6.533725523110083 m
# 23 Result: 0.002038850971128475
# 23 Should be: 2.038850971128475 m
# 29 Result: 0.0061294235661365475
# 29 Should be: 6.1294235661365475 m

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step3_enlem[i],step3_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step3_enlem[i],step3_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step4_enlem = []   #enlem
step4_boylam = []   #boylam

def move_north(i):
  k = float(step3_enlem[i] + 0.00005968)
  step4_enlem.append(k)
  l = step3_boylam[i]
  step4_boylam.append(l)
  folium.Marker(location=[k,step3_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step3_enlem[i] - 0.00005968)
  step4_enlem.append(k)
  l = step3_boylam[i]
  step4_boylam.append(l)
  folium.Marker(location=[k,step3_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step3_boylam[i] + 0.00005968)
  step4_boylam.append(k)
  l = step3_enlem[i]
  step4_enlem.append(l)
  folium.Marker(location=[step3_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step3_boylam[i] - 0.00005968)
  step4_boylam.append(k)
  l = step3_enlem[i]
  step4_enlem.append(l)
  folium.Marker(location=[step3_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step4_enlem)):
  lat1 = radians(step4_enlem[k])
  lon1 = radians(step4_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step4_enlem[i])
    lon2 = radians(step4_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 16 Result: 0.007338047421836817
# 16 Should be: 7.338047421836817 m
# 22 Result: 0.006533725523110083
# 22 Should be: 6.533725523110083 m
# 23 Result: 0.002038850971128475
# 23 Should be: 2.038850971128475 m
# 29 Result: 0.0061294235657014615
# 29 Should be: 6.129423565701462 m

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step4_enlem[i],step4_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step4_enlem[i],step4_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step5_enlem = []   #enlem
step5_boylam = []   #boylam

def move_north(i):
  k = float(step4_enlem[i] + 0.00005968)
  step5_enlem.append(k)
  l = step4_boylam[i]
  step5_boylam.append(l)
  folium.Marker(location=[k,step4_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step4_enlem[i] - 0.00005968)
  step5_enlem.append(k)
  l = step4_boylam[i]
  step5_boylam.append(l)
  folium.Marker(location=[k,step4_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step4_boylam[i] + 0.00005968)
  step5_boylam.append(k)
  l = step4_enlem[i]
  step5_enlem.append(l)
  folium.Marker(location=[step4_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step4_boylam[i] - 0.00005968)
  step5_boylam.append(k)
  l = step4_enlem[i]
  step5_enlem.append(l)
  folium.Marker(location=[step4_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step5_enlem)):
  lat1 = radians(step5_enlem[k])
  lon1 = radians(step5_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step5_enlem[i])
    lon2 = radians(step5_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 16 Result: 0.006484936266852684
# 16 Should be: 6.484936266852684 m
# 22 Result: 0.0031479444381498183
# 22 Should be: 3.147944438149818 m
# 23 Result: 0.002038850971128475
# 23 Should be: 2.038850971128475 m
# 24 Result: 0.00973865759790732
# 24 Should be: 9.73865759790732 m

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step5_enlem[i],step5_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step5_enlem[i],step5_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step6_enlem = []   #enlem
step6_boylam = []   #boylam

def move_north(i):
  k = float(step5_enlem[i] + 0.00005968)
  step6_enlem.append(k)
  l = step5_boylam[i]
  step6_boylam.append(l)
  folium.Marker(location=[k,step5_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step5_enlem[i] - 0.00005968)
  step6_enlem.append(k)
  l = step5_boylam[i]
  step6_boylam.append(l)
  folium.Marker(location=[k,step5_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step5_boylam[i] + 0.00005968)
  step6_boylam.append(k)
  l = step5_enlem[i]
  step6_enlem.append(l)
  folium.Marker(location=[step5_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step5_boylam[i] - 0.00005968)
  step6_boylam.append(k)
  l = step5_enlem[i]
  step6_enlem.append(l)
  folium.Marker(location=[step5_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step6_enlem)):
  lat1 = radians(step6_enlem[k])
  lon1 = radians(step6_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step6_enlem[i])
    lon2 = radians(step6_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 16 Result: 0.006484936266852684
# 16 Should be: 6.484936266852684 m
# 17 Result: 0.00776452467030748
# 17 Should be: 7.7645246703074795 m
# 23 Result: 0.008331019846113315
# 23 Should be: 8.331019846113316 m
# 24 Result: 0.007140931557707324
# 24 Should be: 7.140931557707323 m
# 29 Result: 0.006517417320096079
# 29 Should be: 6.517417320096079 m

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step6_enlem[i],step6_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step6_enlem[i],step6_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step7_enlem = []   #enlem
step7_boylam = []   #boylam

def move_north(i):
  k = float(step6_enlem[i] + 0.00005968)
  step7_enlem.append(k)
  l = step6_boylam[i]
  step7_boylam.append(l)
  folium.Marker(location=[k,step6_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step6_enlem[i] - 0.00005968)
  step7_enlem.append(k)
  l = step6_boylam[i]
  step7_boylam.append(l)
  folium.Marker(location=[k,step6_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step6_boylam[i] + 0.00005968)
  step7_boylam.append(k)
  l = step6_enlem[i]
  step7_enlem.append(l)
  folium.Marker(location=[step6_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step6_boylam[i] - 0.00005968)
  step7_boylam.append(k)
  l = step6_enlem[i]
  step7_enlem.append(l)
  folium.Marker(location=[step6_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step7_enlem)):
  lat1 = radians(step7_enlem[k])
  lon1 = radians(step7_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step7_enlem[i])
    lon2 = radians(step7_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 16 Result: 0.006484936266852684
# 16 Should be: 6.484936266852684 m
# 17 Result: 0.007467666763722027
# 17 Should be: 7.467666763722027 m
# 23 Result: 0.008331019846113315
# 23 Should be: 8.331019846113316 m
# 24 Result: 0.007140931557707324
# 24 Should be: 7.140931557707323 m

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step7_enlem[i],step7_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step7_enlem[i],step7_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step8_enlem = []   #enlem
step8_boylam = []   #boylam

def move_north(i):
  k = float(step7_enlem[i] + 0.00005968)
  step8_enlem.append(k)
  l = step7_boylam[i]
  step8_boylam.append(l)
  folium.Marker(location=[k,step7_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step7_enlem[i] - 0.00005968)
  step8_enlem.append(k)
  l = step7_boylam[i]
  step8_boylam.append(l)
  folium.Marker(location=[k,step7_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step7_boylam[i] + 0.00005968)
  step8_boylam.append(k)
  l = step7_enlem[i]
  step8_enlem.append(l)
  folium.Marker(location=[step7_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step7_boylam[i] - 0.00005968)
  step8_boylam.append(k)
  l = step7_enlem[i]
  step8_enlem.append(l)
  folium.Marker(location=[step7_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step8_enlem)):
  lat1 = radians(step8_enlem[k])
  lon1 = radians(step8_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step8_enlem[i])
    lon2 = radians(step8_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 16 Result: 0.006484936266852684
# 16 Should be: 6.484936266852684 m
# 17 Result: 0.007467666025268528
# 17 Should be: 7.467666025268528 m
# 24 Result: 0.007140928795245843
# 24 Should be: 7.140928795245842 m
# 29 Result: 0.003095650656944504
# 29 Should be: 3.095650656944504 m

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step8_enlem[i],step8_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step8_enlem[i],step8_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step9_enlem = []   #enlem
step9_boylam = []   #boylam

def move_north(i):
  k = float(step8_enlem[i] + 0.00005968)
  step9_enlem.append(k)
  l = step8_boylam[i]
  step9_boylam.append(l)
  folium.Marker(location=[k,step8_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step8_enlem[i] - 0.00005968)
  step9_enlem.append(k)
  l = step8_boylam[i]
  step9_boylam.append(l)
  folium.Marker(location=[k,step8_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step8_boylam[i] + 0.00005968)
  step9_boylam.append(k)
  l = step8_enlem[i]
  step9_enlem.append(l)
  folium.Marker(location=[step8_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step8_boylam[i] - 0.00005968)
  step9_boylam.append(k)
  l = step8_enlem[i]
  step9_enlem.append(l)
  folium.Marker(location=[step8_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step9_enlem)):
  lat1 = radians(step9_enlem[k])
  lon1 = radians(step9_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step9_enlem[i])
    lon2 = radians(step9_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 5 Connected gateway: 9.834216310074654 m
# 6 Connected gateway: 9.834216310074654 m
# 7 Connected gateway: 9.834216310074654 m
# 8 Connected gateway: 9.834216310074654 m
# 9 Connected gateway: 9.834216310074654 m
# 10 Connected gateway: 9.834216310074654 m
# 11 Connected gateway: 9.834216310074654 m
# 12 Connected gateway: 9.834216310074654 m
# 13 Connected gateway: 9.834216310074654 m
# 14 Connected gateway: 9.834216310074654 m
# 15 Connected gateway: 9.834216310074654 m
# 16 Connected gateway: 9.834216310074654 m
# 17 Result: 0.007476689976675652
# 17 Should be: 7.476689976675652 m
# 17 Connected gateway: 9.834216310074654 m
# 18 Connected gateway: 9.834216310074654 m
# 19 Connected gateway: 9.834216310074654 m
# 20 Connected gateway: 9.834216310074654 m
# 21 Connected gateway: 9.834216310074654 m
# 22 Connected gateway: 9.834216310074654 m
# 23 Connected gateway: 9.834216310074654 m
# 24 Connected gateway: 9.834216310074654 m
# 25 Connected gateway: 9.834216310074654 m
# ...

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step9_enlem[i],step9_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step9_enlem[i],step9_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step10_enlem = []   #enlem
step10_boylam = []   #boylam

def move_north(i):
  k = float(step9_enlem[i] + 0.00005968)
  step10_enlem.append(k)
  l = step9_boylam[i]
  step10_boylam.append(l)
  folium.Marker(location=[k,step9_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step9_enlem[i] - 0.00005968)
  step10_enlem.append(k)
  l = step9_boylam[i]
  step10_boylam.append(l)
  folium.Marker(location=[k,step9_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step9_boylam[i] + 0.00005968)
  step10_boylam.append(k)
  l = step9_enlem[i]
  step10_enlem.append(l)
  folium.Marker(location=[step9_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step9_boylam[i] - 0.00005968)
  step10_boylam.append(k)
  l = step9_enlem[i]
  step10_enlem.append(l)
  folium.Marker(location=[step9_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step10_enlem)):
  lat1 = radians(step10_enlem[k])
  lon1 = radians(step10_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step10_enlem[i])
    lon2 = radians(step10_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 27 Result: 0.00799606693642946
# 27 Should be: 7.996066936429459 m
# 29 Result: 0.006129412436900205
# 29 Should be: 6.129412436900205 m

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step10_enlem[i],step10_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step10_enlem[i],step10_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step11_enlem = []   #enlem
step11_boylam = []   #boylam

def move_north(i):
  k = float(step10_enlem[i] + 0.00005968)
  step11_enlem.append(k)
  l = step10_boylam[i]
  step11_boylam.append(l)
  folium.Marker(location=[k,step10_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step10_enlem[i] - 0.00005968)
  step11_enlem.append(k)
  l = step10_boylam[i]
  step11_boylam.append(l)
  folium.Marker(location=[k,step10_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step10_boylam[i] + 0.00005968)
  step11_boylam.append(k)
  l = step10_enlem[i]
  step11_enlem.append(l)
  folium.Marker(location=[step10_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step10_boylam[i] - 0.00005968)
  step11_boylam.append(k)
  l = step10_enlem[i]
  step11_enlem.append(l)
  folium.Marker(location=[step10_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step11_enlem)):
  lat1 = radians(step11_enlem[k])
  lon1 = radians(step11_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step11_enlem[i])
    lon2 = radians(step11_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 5 Connected gateway: 7.624871468471514 m
# 6 Connected gateway: 7.624871468471514 m
# 7 Connected gateway: 7.624871468471514 m
# 8 Connected gateway: 7.624871468471514 m
# 9 Connected gateway: 7.624871468471514 m
# 10 Connected gateway: 7.624871468471514 m
# 11 Connected gateway: 7.624871468471514 m
# 12 Connected gateway: 7.624871468471514 m
# 13 Connected gateway: 7.624871468471514 m
# 14 Connected gateway: 7.624871468471514 m
# 15 Connected gateway: 7.624871468471514 m
# 16 Connected gateway: 7.624871468471514 m
# 17 Connected gateway: 7.624871468471514 m
# 18 Connected gateway: 7.624871468471514 m
# 19 Connected gateway: 7.624871468471514 m
# 20 Connected gateway: 7.624871468471514 m
# 21 Connected gateway: 7.624871468471514 m
# 22 Connected gateway: 7.624871468471514 m
# 23 Connected gateway: 7.624871468471514 m
# 24 Connected gateway: 7.624871468471514 m
# 25 Connected gateway: 7.624871468471514 m
# 26 Connected gateway: 7.624871468471514 m
# ...

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step11_enlem[i],step11_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step11_enlem[i],step11_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
a = [1,1,1,1,2,3,3,3,3,4]
step12_enlem = []   #enlem
step12_boylam = []   #boylam

def move_north(i):
  k = float(step11_enlem[i] + 0.00005968)
  step12_enlem.append(k)
  l = step11_boylam[i]
  step12_boylam.append(l)
  folium.Marker(location=[k,step11_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_south(i):
  k = float(step11_enlem[i] - 0.00005968)
  step12_enlem.append(k)
  l = step11_boylam[i]
  step12_boylam.append(l)
  folium.Marker(location=[k,step11_boylam[i]],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_west(i):
  k = float(step11_boylam[i] + 0.00005968)
  step12_boylam.append(k)
  l = step11_enlem[i]
  step12_enlem.append(l)
  folium.Marker(location=[step11_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

def move_east(i):
  k = float(step11_boylam[i] - 0.00005968)
  step12_boylam.append(k)
  l = step11_enlem[i]
  step12_enlem.append(l)
  folium.Marker(location=[step11_enlem[i],k],tooltip=i,icon=folium.Icon(color="orange")).add_to(m)

for i in range (apps):
  switch = random.choice(a)
  if switch == 1:
    move_north(i)
  elif switch == 2:
    move_south(i)
  elif switch == 3:
    move_west(i)
  elif switch == 4:
    move_east(i)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from math import sin, cos, sqrt, atan2, radians


def calculate(lat1,lon1,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon1 - lon2
  dlat = lat1 - lat2

  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  if metre <= 10:
    print(k,"Result:", distance)
    print(k,"Should be:", metre , "m")

def calculate_gateway(lat3,lon3,lat2,lon2):
  # approximate radius of earth in km
  R = 6373.0

  dlon = lon3 - lon2
  dlat = lat3 - lat2

  a = sin(dlat / 2)**2 + cos(lat3) * cos(lat2) * sin(dlon / 2)**2
  c = 2 * atan2(sqrt(a), sqrt(1 - a))

  distance = R * c
  metre = distance*1000
  
  if metre <= 10:
    print(k,"Connected gateway:", metre , "m")

  

for k in range(len(step12_enlem)):
  lat1 = radians(step12_enlem[k])
  lon1 = radians(step12_boylam[k])
  lat3 = radians(41.103876)
  lon3 = radians(29.022749)
  for i in range(k):
    lat2 = radians(step12_enlem[i])
    lon2 = radians(step12_boylam[i])
    calculate(lat1,lon1,lat2,lon2)
    calculate_gateway(lat3,lon3,lat2,lon2)
# Out:
# 5 Connected gateway: 3.6026902743396407 m
# 6 Connected gateway: 3.6026902743396407 m
# 7 Connected gateway: 3.6026902743396407 m
# 8 Connected gateway: 3.6026902743396407 m
# 9 Connected gateway: 3.6026902743396407 m
# 10 Connected gateway: 3.6026902743396407 m
# 11 Connected gateway: 3.6026902743396407 m
# 12 Connected gateway: 3.6026902743396407 m
# 13 Connected gateway: 3.6026902743396407 m
# 14 Connected gateway: 3.6026902743396407 m
# 14 Result: 0.005424770927631752
# 14 Should be: 5.424770927631752 m
# 15 Connected gateway: 3.6026902743396407 m
# 16 Connected gateway: 3.6026902743396407 m
# 17 Result: 0.00747668320260223
# 17 Should be: 7.47668320260223 m
# 17 Connected gateway: 3.6026902743396407 m
# 18 Connected gateway: 3.6026902743396407 m
# 18 Connected gateway: 6.425090743938309 m
# 19 Connected gateway: 3.6026902743396407 m
# 19 Connected gateway: 6.425090743938309 m
# 20 Connected gateway: 3.6026902743396407 m
# 20 Connected gateway: 6.425090743938309 m
# ...

# %%
m = folium.Map(location=[41.104385,29.022716] ,zoom_start =20)
folium.Marker(location=[41.103876,29.022749],tooltip="Gateway",icon=folium.Icon(color='green')).add_to(m)
for i in range(apps):
  folium.Marker(location=[step12_enlem[i],step12_boylam[i]],tooltip=i,icon=folium.Icon(color="red")).add_to(m)
  folium.CircleMarker(
      location=[step12_enlem[i],step12_boylam[i]],
      radius=10,
      color='red',
      fill=True,
      fill_color='red'
  ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
